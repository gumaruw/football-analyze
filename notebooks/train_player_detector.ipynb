# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # Train Soccer Player Detector
#
# ---
#
# [![Download Dataset](https://app.roboflow.com/images/download-dataset-badge.svg)](https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc)
#
# This notebook is based on the [How to Train YOLOv8 Object Detection on a Custom Dataset](https://github.com/roboflow/notebooks/blob/main/notebooks/train-yolov8-object-detection-on-custom-dataset.ipynb) notebook from the [roboflow/notebooks](https://github.com/roboflow/notebooks) repository.

# %% [markdown]
# ## Configure API keys
#
# - Open your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑). Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Mon Oct 20 10:11:07 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install dependencies

# %%
# !pip install -q ultralytics roboflow

# %% [markdown]
# ## Imports

# %%
from roboflow import Roboflow
from google.colab import userdata
from IPython.display import Image

# %% [markdown]
# ## Pull dataset

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

from google.colab import userdata # Import userdata

ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')
rf = Roboflow(api_key=ROBOFLOW_API_KEY)

project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(20)
dataset = version.download("yolov8")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# **NOTE:** Update `data.yaml` structure to align with the latest requirements of the `ultralytics` package.

# %%
# !sed -i 's|\(train: \).*|\1../train/images|' {dataset.location}/data.yaml
# !sed -i 's|\(val: \).*|\1../valid/images|' {dataset.location}/data.yaml

# %% [markdown]
# ## Custom training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml batch=5 epochs=50 imgsz=1280 plots=True
# Out:
# /content
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=5, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/datasets/football-players-detection-20/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1280, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8x.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train5, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8721820  ultralytics.nn.modules.head.Detect           [4, [320, 640, 640]]
# Model summary: 209 layers, 68,156,460 parameters, 68,156,444 gradients, 258.1 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1768.2±466.5 MB/s, size: 50.8 KB)
# train: Scanning /content/datasets/football-players-detection-20/train/labels.cache... 298 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 298/298 5.0Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 897.8±723.3 MB/s, size: 48.2 KB)
# val: Scanning /content/datasets/football-players-detection-20/valid/labels.cache... 49 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 49/49 22.3Kit/s 0.0s
# Plotting labels to /content/runs/detect/train5/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005078125), 103 bias(decay=0.0)
# Image sizes 1280 train, 1280 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train5
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      14.4G      1.257      1.406      1.013         76       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.6s
#                    all         49       1174      0.271      0.331       0.21       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      14.5G      1.216      1.066      1.001        109       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.7it/s 6.7s
#                    all         49       1174      0.208     0.0532     0.0393     0.0151
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      14.5G       1.41      1.614      1.049        122       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.605      0.253      0.281      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      14.3G       1.31      1.158      1.026         45       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.6s
#                    all         49       1174      0.472      0.311      0.286      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      14.6G      1.252     0.9535      1.021         91       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.7it/s 6.9s
#                    all         49       1174      0.263     0.0525     0.0957     0.0566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      14.3G      1.191     0.7975     0.9815         88       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174       0.56      0.547      0.582      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      14.4G        1.2     0.7379     0.9833         98       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.736      0.702      0.737      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      14.4G      1.149     0.6844     0.9789         48       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.718      0.727      0.752      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      14.4G      1.033     0.7157      1.033        109       1280: 3% ──────────── 2/60 0.3it/s 5.0s<3:08WARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#        9/50      14.4G      1.138     0.6939     0.9969        145       1280: 13% ━╸────────── 8/60 0.6it/s 16.6s<1:34WARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#        9/50      14.4G       1.13     0.6804     0.9834        138       1280: 17% ━━────────── 10/60 0.5it/s 22.2s<1:39WARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#        9/50      14.4G      1.142      0.665     0.9723        181       1280: 37% ━━━━──────── 22/60 0.6it/s 44.1s<1:05WARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#        9/50      14.4G      1.135     0.6644     0.9695        241       1280: 47% ━━━━━╸────── 28/60 0.6it/s 55.7s<54.9sWARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#        9/50      14.4G      1.131     0.6604     0.9658        123       1280: 58% ━━━━━━━───── 35/60 0.6it/s 1:09<41.8sWARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#        9/50      14.4G      1.136     0.6618     0.9654        287       1280: 60% ━━━━━━━───── 36/60 0.5it/s 1:12<47.7sWARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#        9/50      14.4G      1.137       0.66     0.9676        137       1280: 63% ━━━━━━━╸──── 38/60 0.5it/s 1:17<44.4sWARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#        9/50      14.4G      1.132     0.6562     0.9686        168       1280: 83% ━━━━━━━━━━── 50/60 0.6it/s 1:40<16.7sWARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#        9/50      14.4G       1.13      0.656     0.9686         97       1280: 90% ━━━━━━━━━━╸─ 54/60 0.6it/s 1:48<10.7sWARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#        9/50      14.4G      1.126     0.6525     0.9669         94       1280: 100% ━━━━━━━━━━━━ 60/60 0.5it/s 1:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.745      0.752       0.75      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      14.5G      1.077     0.6346     0.9585        191       1280: 17% ━━────────── 10/60 0.6it/s 18.3s<1:25WARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       10/50      14.5G      1.065     0.6283     0.9423        103       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.824      0.764      0.799      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      14.4G     0.9939     0.6197      0.939        123       1280: 10% ━─────────── 6/60 0.5it/s 11.6s<1:41WARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       11/50      14.4G      1.009     0.6213     0.9415        116       1280: 13% ━╸────────── 8/60 0.5it/s 17.4s<1:45WARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       11/50      14.4G      1.021      0.661      0.944        174       1280: 30% ━━━╸──────── 18/60 0.6it/s 36.0s<1:12WARNING ⚠️ CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#
1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.893      0.838      0.876      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      14.6G     0.8129     0.3773     0.8805         71       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.909      0.848      0.889      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      14.5G     0.7982     0.3691     0.8733         71       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.895      0.842      0.882      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      14.4G     0.8003     0.3685     0.8813         70       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.901      0.833      0.883      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      14.6G     0.7764     0.3584      0.866         71       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.882      0.848      0.885      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      14.6G      0.775     0.3528     0.8696         72       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.886      0.862      0.889      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      14.4G     0.7797     0.3529     0.8735         68       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.903      0.843      0.882      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      14.5G      0.779     0.3495     0.8714         67       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.874       0.87      0.889      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      14.6G      0.775     0.3502     0.8615         71       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.877      0.857      0.883      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      14.4G     0.7606     0.3423     0.8691         68       1280: 100% ━━━━━━━━━━━━ 60/60 0.6it/s 1:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.8it/s 6.4s
#                    all         49       1174      0.891      0.857      0.894      0.602
#
# 50 epochs completed in 1.638 hours.
# Optimizer stripped from /content/runs/detect/train5/weights/last.pt, 136.9MB
# Optimizer stripped from /content/runs/detect/train5/weights/best.pt, 136.9MB
#
# Validating /content/runs/detect/train5/weights/best.pt...
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 68,127,420 parameters, 0 gradients, 257.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.6it/s 8.7s
#                    all         49       1174      0.891      0.857      0.894      0.601
#                   ball         45         45      0.813      0.579      0.668      0.306
#             goalkeeper         38         39      0.852      0.923      0.941      0.685
#                 player         49        973      0.965      0.986      0.993      0.778
#                referee         49        117      0.934       0.94      0.973      0.637
# Speed: 1.2ms preprocess, 121.2ms inference, 0.0ms loss, 14.7ms postprocess per image
# Results saved to /content/runs/detect/train5
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !ls {HOME}/runs/detect/train5/
# Out:
# args.yaml			 results.csv	      val_batch0_labels.jpg
# BoxF1_curve.png			 results.png	      val_batch0_pred.jpg
# BoxP_curve.png			 train_batch0.jpg     val_batch1_labels.jpg
# BoxPR_curve.png			 train_batch1.jpg     val_batch1_pred.jpg
# BoxR_curve.png			 train_batch2400.jpg  val_batch2_labels.jpg
# confusion_matrix_normalized.png  train_batch2401.jpg  val_batch2_pred.jpg
# confusion_matrix.png		 train_batch2402.jpg  weights
# labels.jpg			 train_batch2.jpg

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train5/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train5/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train5/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate custom model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train5/weights/best.pt data={dataset.location}/data.yaml imgsz=1280
# Out:
# /content
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 420, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 97, in __init__
#     self._load(model, task)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 149, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 628, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#                    ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 567, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1529, in load
#     raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# _pickle.UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL ultralytics.nn.tasks.DetectionModel was not an allowed global by default. Please use `torch.serialization.add_safe_globals([ultralytics.nn.tasks.DetectionModel])` or the `torch.serialization.safe_globals([ultralytics.nn.tasks.DetectionModel])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.

# %% [markdown]
# ## Deploy model on Roboflow

# %%
# @title
pip install ultralytics==8.0.196
# Out:
# Collecting ultralytics==8.0.196
#   Downloading ultralytics-8.0.196-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (3.10.0)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (2.0.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (0.23.0+cu126)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (4.67.1)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (0.13.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics==8.0.196)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.0.196) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.0.196) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.0.196) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.0.196) (2025.10.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.0.196) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics==8.0.196) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics==8.0.196) (3.0.3)
# Downloading ultralytics-8.0.196-py3-none-any.whl (631 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 49.0 MB/s eta 0:00:00
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop, ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.217
#     Uninstalling ultralytics-8.3.217:
#       Successfully uninstalled ultralytics-8.3.217
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.0.196

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train5/")
# Out:
# An error occured when getting the model upload URL: 404 Client Error: Not Found for url: https://api.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/20/uploadModel?api_key=sqhPnzqqtV3f7IfwoISz&modelType=yolov8&nocache=true

# %%
# !ls {HOME}/runs/detect/train5/weights/
# Out:
# best.pt  last.pt

# %%
from google.colab import files
files.download('/content/runs/detect/train5/weights/best.pt')
